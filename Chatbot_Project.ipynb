# %% [markdown]
# **MSBA 316 Final Project**: **Virtual Teacher for Text Analytics and Natural Language Processing** <br>
# **By:** <br>
# - Mohammad Mohsen 201703270 <br>
# - Amir Bazzi 201702885<br>
# - Mahdi Mohammad 201804517 <br>
#
# **Prupose:** The purpose of this notebook present the process that was followed in order to create the chatbot, the chosen model will be saved and then used in the deployed app on this link:....

# %% [markdown]
# # **Importing Librabries**

# %%
import random
import warnings
import json
import numpy as np
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
import re
import spacy
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
from spacy.lang.en.stop_words import STOP_WORDS
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score, auc
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics.pairwise import cosine_similarity 
from tensorflow import keras
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
warnings.filterwarnings('ignore')

# %%
# Launching spacy
nlp = spacy.load("en_core_web_sm")

# %%
# Mounting the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Intent Classification**

# %% [markdown]
# ## Data Preparation

# %%
# loading the intent file
data_file = open('/content/drive/MyDrive/intents.json').read()
intents_patterns = json.loads(data_file)

# %%
# preparing the data to be ready for machine learning
data = []
for intent in intents_patterns['intents']:
  for pattern in intent['patterns']:
    data.append((pattern , intent['tag']))

tags = [intent['tag'] for intent in intents_patterns['intents']]

intent_df= pd.DataFrame(data = data, columns = ['pattern', 'intent'])
intent_df
# Out:
#                                            pattern  \
# 0                                               Hi
# 1                                            Hello
# 2                                              Hey
# 3                                        greetings
# 4                                peace be upon you
# ..                                             ...
# 132  why is nlp or natual language processing hard
# 133                     What is text preprocessing
# 134                   What are regular expressions
# 135                            What are Stop words
# 136                    What is feature engineering
#
#                           intent
# 0                       greeting
# 1                       greeting
# 2                       greeting
# 3                       greeting
# 4                       greeting
# ..                           ...
# 132  Natural Language Processing
# 133  Natural Language Processing
# 134  Natural Language Processing
# 135  Natural Language Processing
# 136  Natural Language Processing
#
# [137 rows x 2 columns]

# %% [markdown]
# ## Pattern Preprocessing

# %%
# a function to normalize the text
def normalize_doc(text):
  # lower case and remove special characters\whitespaces
  text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
  text = text.lower()
  # lemmatization
  #doc = nlp(text)
  #lemmas = [token.lemma_ for token in doc]
  # re-create document from lemmas
  #text = ' '.join(lemmas)
  return text

# %%
intent_df['pattern_normalized'] = intent_df['pattern'].apply(normalize_doc)

# %%
intent_df.head()
# Out:
#              pattern    intent pattern_normalized
# 0                 Hi  greeting                 hi
# 1              Hello  greeting              hello
# 2                Hey  greeting                hey
# 3          greetings  greeting          greetings
# 4  peace be upon you  greeting  peace be upon you

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### TFIDF

# %%
# Extract the feature column and the target variable
X = intent_df['pattern_normalized']
y = intent_df['intent']

# Perform Splitting
x_train , x_test, y_train , y_test = train_test_split(X, y, test_size = 0.25, random_state = 111, stratify = y)

# %%
# instantiating the tfidf vectorizer
tf_ml = TfidfVectorizer()

# matrix for training
X_train_tfidf = tf_ml.fit_transform(x_train)

# matrix for testing
X_test_tfidf = tf_ml.transform(x_test)

# %% [markdown]
# ### BERT

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.7/dist-packages (2.2.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.12.0+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.8.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.13.0+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.21.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.1.96)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.6.15)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)

# %%
from sentence_transformers import SentenceTransformer
# instantiating the embedder 
embedder = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')

# %%
# vectorizing the corpus using embeddings
corpus_embeddings = embedder.encode(X)
corpus_embeddings.shape

# splitting the embeddings data
x_train_emb , x_test_emb , y_train_emb , y_test_emb = train_test_split(corpus_embeddings, y, test_size = 0.25, random_state = 111, stratify = y)

# %% [markdown]
# ## Baseline Model for Intent Classification (Cosine Similarity)

# %%
# Cosine similarity method using TFIDF vectorization
y_pred_cos=[]
for i in range(X_test_tfidf.shape[0]):
  scores = cosine_similarity(X_train_tfidf, X_test_tfidf[i])
  y_pred_cos.append(y_train.iloc[np.argmax(scores)])

# Accuracy of cos
accuracy_cos = accuracy_score(y_test,y_pred_cos)*100
accuracy_cos
# Out:
# 40.0

# %%
# Cosine similarity method using Bert vectorization
y_pred_bert=[]
for i in range(x_test_emb.shape[0]):
  scores = cosine_similarity(x_train_emb, x_test_emb[i].reshape(1, -1))
  y_pred_bert.append(y_train_emb.iloc[np.argmax(scores)])

# Accuracy of bert
accuracy_bert = accuracy_score(y_test_emb,y_pred_bert)*100
accuracy_bert
# Out:
# 74.28571428571429

# %% [markdown]
# ## Machine Learning Approach

# %% [markdown]
# ### Models Definition

# %%
# a function to train and test the model
def train_test_model(model, x_train, x_test, y_train, y_test):
  # training the model
  model.fit(x_train, y_train)
  # predicting the test data
  y_pred = model.predict(x_test)
  acc = accuracy_score(y_test, y_pred)
  return acc

# %%
# instanstiating several models
lr_tfidf = LogisticRegression(max_iter=10000)
svm_tfidf = SVC()
clf_tfidf = DecisionTreeClassifier(random_state=0)
ens_clf_tfidf = RandomForestClassifier(10000)
all_models_tfidf = [lr_tfidf, svm_tfidf, clf_tfidf, ens_clf_tfidf]

# %% [markdown]
# ### ML Models Using TFIDF

# %% [markdown]
# #### Running Models

# %%
def train_tfidf():
  model_performance_tf_idf = {}
  for model in all_models_tfidf:
    model_performance_tf_idf[model] = (train_test_model(model, X_train_tfidf, X_test_tfidf, y_train, y_test))
  return model_performance_tf_idf

# %%
train_tfidf()
# Out:
# {DecisionTreeClassifier(random_state=0): 0.2571428571428571,
#  LogisticRegression(max_iter=10000): 0.3142857142857143,
#  RandomForestClassifier(n_estimators=10000): 0.34285714285714286,
#  SVC(): 0.2}

# %% [markdown]
# #### Optimizing Models

# %%
lr = LogisticRegression()

# %%
param_grid = [{'penalty': ['l1', 'l2', 'elasticnet', 'none'], 'solver' : ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],'max_iter': [7000,10000]}]
grid_search = GridSearchCV(lr, param_grid, verbose=2, n_jobs=-1)
grid_search.fit(X_train_tfidf , y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid=[{'max_iter': [7000, 10000],
#                           'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                           'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                      'saga']}],
#              verbose=2)

# %%
lr = LogisticRegression(max_iter= grid_search.best_params_['max_iter'], penalty= grid_search.best_params_['penalty'], solver= grid_search.best_params_['solver'])

# %%
train_test_model(lr, X_train_tfidf, X_test_tfidf, y_train, y_test)
# Out:
# 0.4

# %% [markdown]
# ### ML Models Using Embeddings (BERT)

# %% [markdown]
# #### Running Models

# %%
# instanstiating several models
lr_emb = LogisticRegression(max_iter=10000)
svm_emb = SVC()
clf_emb = DecisionTreeClassifier(random_state=0)
ens_clf_emb = RandomForestClassifier(10000)
all_models_emb = [lr_emb, svm_emb, clf_emb, ens_clf_emb]

# %%
def train_emb():
  model_performance_embeddings = {}
  for model in all_models_emb:
    model_performance_embeddings[model] = (train_test_model(model, x_train_emb, x_test_emb, y_train_emb, y_test_emb))
  return model_performance_embeddings

# %%
train_emb()
# Out:
# {DecisionTreeClassifier(random_state=0): 0.2857142857142857,
#  LogisticRegression(max_iter=10000): 0.8,
#  RandomForestClassifier(n_estimators=10000): 0.6571428571428571,
#  SVC(): 0.6}

# %% [markdown]
# #### Optimizing Models

# %%
param_grid = [{'penalty': ['l2', 'none'], 'solver' : ['liblinear', 'sag', 'saga'],'max_iter': [7000,10000]}]

grid_search = GridSearchCV(lr, param_grid, verbose=2, n_jobs=-1)
grid_search.fit(x_train_emb , y_train_emb)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=LogisticRegression(max_iter=7000, penalty='none',
#                                           solver='sag'),
#              n_jobs=-1,
#              param_grid=[{'max_iter': [7000, 10000], 'penalty': ['l2', 'none'],
#                           'solver': ['liblinear', 'sag', 'saga']}],
#              verbose=2)

# %%
lr = LogisticRegression(max_iter= grid_search.best_params_['max_iter'], penalty=grid_search.best_params_['penalty'], solver= grid_search.best_params_['solver'])

# %%
train_test_model(lr, x_train_emb, x_test_emb, y_train_emb, y_test_emb)
# Out:
# 0.7714285714285715

# %% [markdown]
# ## Neural Network Approach

# %% [markdown]
# ### NN Preprocessing (Encoding Intent)

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(y)
encoded_Y = encoder.transform(y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)

label_decoder = dict(zip(y, dummy_y))

# %% [markdown]
# ### Using TFIDF

# %%
tf_neural = TfidfVectorizer()
tf_matrix_keras = tf_neural.fit_transform(X)
dense_features = tf_matrix_keras.todense()

# %%
# Create model_tfidf - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model_tfidf = Sequential()
model_tfidf.add(Dense(128, input_shape=(dense_features.shape[1],), activation='relu'))
model_tfidf.add(Dropout(0.5))
model_tfidf.add(Dense(64, activation='relu'))
model_tfidf.add(Dropout(0.5))
model_tfidf.add(Dense(len(dummy_y[0]),activation='softmax'))

# Compile model_tfidf. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model_tfidf
sgd = SGD(learning_rate = 0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_tfidf.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model_tfidf 
hist = model_tfidf.fit(dense_features.astype('float32'), dummy_y, epochs=400, verbose=1)
#model_tfidf.save('chatbot_model_tfidf.h5', hist)

print("model_tfidf created")
# Out:
# Epoch 1/400
# 5/5 [==============================] - 1s 4ms/step - loss: 3.4660 - accuracy: 0.0365
# Epoch 2/400
# 5/5 [==============================] - 0s 4ms/step - loss: 3.4623 - accuracy: 0.0365
# Epoch 3/400
# 5/5 [==============================] - 0s 5ms/step - loss: 3.4610 - accuracy: 0.0073
# Epoch 4/400
# 5/5 [==============================] - 0s 4ms/step - loss: 3.4573 - accuracy: 0.0438
# Epoch 5/400
# 5/5 [==============================] - 0s 4ms/step - loss: 3
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4994 - accuracy: 0.8759
# Epoch 324/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4699 - accuracy: 0.8540
# Epoch 325/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3943 - accuracy: 0.9124
# Epoch 326/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4852 - accuracy: 0.8978
# Epoch 327/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3753 - accuracy: 0.9051
# Epoch 328/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4608 - accuracy: 0.8978
# Epoch 329/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5055 - accuracy: 0.8321
# Epoch 330/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3840 - accuracy: 0.9124
# Epoch 331/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4268 - accuracy: 0.9124
# Epoch 332/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4573 - accuracy: 0.9124
# Epoch 333/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4489 - accuracy: 0.8978
# Epoch 334/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4637 - accuracy: 0.8759
# Epoch 335/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4219 - accuracy: 0.8905
# Epoch 336/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3859 - accuracy: 0.8905
# Epoch 337/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4043 - accuracy: 0.8905
# Epoch 338/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5568 - accuracy: 0.8467
# Epoch 339/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3847 - accuracy: 0.9051
# Epoch 340/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4519 - accuracy: 0.8321
# Epoch 341/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4637 - accuracy: 0.8613
# Epoch 342/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4687 - accuracy: 0.8467
# Epoch 343/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4199 - accuracy: 0.8759
# Epoch 344/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3309 - accuracy: 0.9270
# Epoch 345/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3587 - accuracy: 0.9124
# Epoch 346/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3733 - accuracy: 0.9124
# Epoch 347/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4483 - accuracy: 0.8905
# Epoch 348/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3913 - accuracy: 0.9124
# Epoch 349/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4539 - accuracy: 0.8832
# Epoch 350/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3352 - accuracy: 0.9416
# Epoch 351/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4984 - accuracy: 0.8686
# Epoch 352/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3688 - accuracy: 0.9051
# Epoch 353/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4885 - accuracy: 0.8759
# Epoch 354/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4781 - accuracy: 0.8686
# Epoch 355/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4018 - accuracy: 0.8759
# Epoch 356/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3574 - accuracy: 0.9270
# Epoch 357/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3990 - accuracy: 0.9197
# Epoch 358/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3841 - accuracy: 0.8832
# Epoch 359/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3756 - accuracy: 0.9124
# Epoch 360/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3709 - accuracy: 0.9124
# Epoch 361/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3698 - accuracy: 0.8978
# Epoch 362/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3403 - accuracy: 0.9051
# Epoch 363/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4056 - accuracy: 0.9124
# Epoch 364/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4045 - accuracy: 0.8686
# Epoch 365/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4677 - accuracy: 0.8905
# Epoch 366/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3674 - accuracy: 0.9124
# Epoch 367/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3649 - accuracy: 0.9197
# Epoch 368/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.8759
# Epoch 369/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3143 - accuracy: 0.9270
# Epoch 370/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3395 - accuracy: 0.9270
# Epoch 371/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2907 - accuracy: 0.9562
# Epoch 372/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3203 - accuracy: 0.9270
# Epoch 373/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3591 - accuracy: 0.8832
# Epoch 374/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4028 - accuracy: 0.9051
# Epoch 375/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3515 - accuracy: 0.9124
# Epoch 376/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3928 - accuracy: 0.8978
# Epoch 377/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4122 - accuracy: 0.8613
# Epoch 378/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4081 - accuracy: 0.8540
# Epoch 379/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4432 - accuracy: 0.8467
# Epoch 380/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2736 - accuracy: 0.9124
# Epoch 381/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3266 - accuracy: 0.9197
# Epoch 382/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3068 - accuracy: 0.9270
# Epoch 383/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3295 - accuracy: 0.9124
# Epoch 384/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3040 - accuracy: 0.8978
# Epoch 385/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3237 - accuracy: 0.9343
# Epoch 386/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3153 - accuracy: 0.9270
# Epoch 387/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3972 - accuracy: 0.8905
# Epoch 388/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3945 - accuracy: 0.8978
# Epoch 389/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3098 - accuracy: 0.9051
# Epoch 390/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3781 - accuracy: 0.9051
# Epoch 391/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3714 - accuracy: 0.8686
# Epoch 392/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2727 - accuracy: 0.9489
# Epoch 393/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2959 - accuracy: 0.9270
# Epoch 394/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3561 - accuracy: 0.9197
# Epoch 395/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2845 - accuracy: 0.9489
# Epoch 396/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3630 - accuracy: 0.8905
# Epoch 397/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3704 - accuracy: 0.9051
# Epoch 398/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2961 - accuracy: 0.9124
# Epoch 399/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3377 - accuracy: 0.8978
# Epoch 400/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3493 - accuracy: 0.9124
# model_tfidf created

# %% [markdown]
# ### Using Embeddings (BERT)

# %%
# Create model_emb - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model_emb = Sequential()
model_emb.add(Dense(128, input_shape=(768,), activation='relu'))
model_emb.add(Dropout(0.5))
model_emb.add(Dense(64, activation='relu'))
model_emb.add(Dropout(0.5))
model_emb.add(Dense(len(dummy_y[0]),activation='softmax'))

# Compile model_emb. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model_emb
sgd = SGD(learning_rate = 0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_emb.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model_emb 
hist = model_emb.fit(corpus_embeddings, dummy_y, epochs=400, verbose=1)
#model_emb.save('chatbot_model_emb.h5', hist)

print("model_emb created")
# Out:
# Epoch 1/400
# 5/5 [==============================] - 1s 6ms/step - loss: 3.7192 - accuracy: 0.0292
# Epoch 2/400
# 5/5 [==============================] - 0s 6ms/step - loss: 3.5410 - accuracy: 0.0438
# Epoch 3/400
# 5/5 [==============================] - 0s 4ms/step - loss: 3.2980 - accuracy: 0.0949
# Epoch 4/400
# 5/5 [==============================] - 0s 4ms/step - loss: 3.1170 - accuracy: 0.1168
# Epoch 5/400
# 5/5 [==============================] - 0s 7ms/step - loss: 2.8725 - accuracy: 0.2190
# Epoch 6/400
# 5/5 [==============================] - 0s 4ms/step - loss: 2.8897 - accuracy: 0.2336
# Epoch 7/400
# 5/5 [==============================] - 0s 4ms/step - loss: 2.5676 - accuracy: 0.3285
# Epoch 8/400
# 5/5 [==============================] - 0s 5ms/step - loss: 2.4012 - accuracy: 0.2993
# Epoch 9/400
# 5/5 [==============================] - 0s 5ms/step - loss: 2.4570 - accuracy: 0.3285
# Epoch 10/400
# 5/5 [==============================] - 0s 5ms/step - loss: 2.2597 - accuracy: 0.3431
# Epoch 11/400
# 5/5 [==============================] - 0s 5ms/step - loss: 1.9692 - accuracy: 0.4599
# Epoch 12/400
# 5/5 [==============================] - 0s 6ms/step - loss: 1.9521 - accuracy: 0.4526
# Epoch 13/400
# 5/5 [==============================] - 0s 4ms/step - loss: 2.0939 - accuracy: 0.3504
# Epoch 14/400
# 5/5 [==============================] - 0s 4ms/step - loss: 1.9343 - accuracy: 0.4307
# Epoch 15/400
# 5/5 [==============================] - 0s 4ms/step - loss: 1.6971 - accuracy: 0.4964
# Epoch 16/400
# 5/5 [==============================] - 0s 5ms/step - loss: 1.6941 - accuracy: 0.5182
# Epoch 17/400
# 5/5 [==============================] - 0s 5ms/step - loss: 1.7168 - accuracy: 0.4818
# Epoch 18/400
# 5/5 [==============================] - 0s 4ms/step - loss: 1.5654 - accuracy: 0.6058
# Epoch 19/400
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3986 - accuracy: 0.6058
# Epoch 20/400
# 5/5 [==============================] - 0s 4ms/step - loss: 1.3132 - accuracy: 0.6277
# Epoch 21/400
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2558 - accuracy: 0.6642
# Epoch 22/400
# 5/5 [==============================] - 0s 4ms/step - loss: 1.2731 - accuracy: 0.6204
# Epoch 23/400
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1642 - accuracy: 0.6350
# Epoch 24/400
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1429 - accuracy: 0.6934
# Epoch 25/400
# 5/5 [==============================] - 0s 4ms/step - loss: 1.0248 - accuracy: 0.6934
# Epoch 26/400
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1244 - accuracy: 0.6277
# Epoch 27/400
# 5/5 [==============================] - 0s 5ms/step - loss: 1.0405 - accuracy: 0.6642
# Epoch 28/400
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1503 - accuracy: 0.6350
# Epoch 29/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9295 - accuracy: 0.7445
# Epoch 30/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9158 - accuracy: 0.7226
# Epoch 31/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8130 - accuracy: 0.7518
# Epoch 32/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9318 - accuracy: 0.6715
# Epoch 33/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8684 - accuracy: 0.7007
# Epoch 34/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7408 - accuracy: 0.7737
# Epoch 35/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8247 - accuracy: 0.7518
# Epoch 36/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8163 - accuracy: 0.7299
# Epoch 37/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8016 - accuracy: 0.7299
# Epoch 38/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7893 - accuracy: 0.7518
# Epoch 39/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6955 - accuracy: 0.7737
# Epoch 40/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8067 - accuracy: 0.7080
# Epoch 41/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7880 - accuracy: 0.7664
# Epoch 42/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6438 - accuracy: 0.7956
# Epoch 43/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6822 - accuracy: 0.8029
# Epoch 44/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6072 - accuracy: 0.7883
# Epoch 45/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8075 - accuracy: 0.7299
# Epoch 46/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7754 - accuracy: 0.7372
# Epoch 47/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8269 - accuracy: 0.7226
# Epoch 48/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6099 - accuracy: 0.8029
# Epoch 49/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5938 - accuracy: 0.8248
# Epoch 50/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4606 - accuracy: 0.8686
# Epoch 51/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5776 - accuracy: 0.8321
# Epoch 52/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5922 - accuracy: 0.8248
# Epoch 53/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5494 - accuracy: 0.8467
# Epoch 54/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.6759 - accuracy: 0.7664
# Epoch 55/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5997 - accuracy: 0.8102
# Epoch 56/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5341 - accuracy: 0.8394
# Epoch 57/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5517 - accuracy: 0.8175
# Epoch 58/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4606 - accuracy: 0.8613
# Epoch 59/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4872 - accuracy: 0.8248
# Epoch 60/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3841 - accuracy: 0.8759
# Epoch 61/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.4998 - accuracy: 0.8613
# Epoch 62/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5066 - accuracy: 0.8248
# Epoch 63/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4732 - accuracy: 0.8321
# Epoch 64/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5138 - accuracy: 0.8102
# Epoch 65/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5068 - accuracy: 0.8540
# Epoch 66/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3575 - accuracy: 0.8832
# Epoch 67/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4254 - accuracy: 0.8686
# Epoch 68/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4294 - accuracy: 0.8394
# Epoch 69/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.8832
# Epoch 70/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3957 - accuracy: 0.8905
# Epoch 71/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5459 - accuracy: 0.8686
# Epoch 72/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.4052 - accuracy: 0.8540
# Epoch 73/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3849 - accuracy: 0.8905
# Epoch 74/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3473 - accuracy: 0.8832
# Epoch 75/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3014 - accuracy: 0.8978
# Epoch 76/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3207 - accuracy: 0.9197
# Epoch 77/400
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4637 - accuracy: 0.8686
# Epoch 78/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.4642 - accuracy: 0.8613
# Epoch 79/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4473 - accuracy: 0.8613
# Epoch 80/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4451 - accuracy: 0.8686
# Epoch 81/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5402 - accuracy: 0.8029
# Epoch 82/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3679 - accuracy: 0.8759
# Epoch 83/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3127 - accuracy: 0.9051
# Epoch 84/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2756 - accuracy: 0.9051
# Epoch 85/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4167 - accuracy: 0.8394
# Epoch 86/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2428 - accuracy: 0.9197
# Epoch 87/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3964 - accuracy: 0.8759
# Epoch 88/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3013 - accuracy: 0.9197
# Epoch 89/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3050 - accuracy: 0.8832
# Epoch 90/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3145 - accuracy: 0.8905
# Epoch 91/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4332 - accuracy: 0.8759
# Epoch 92/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3529 - accuracy: 0.8540
# Epoch 93/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3966 - accuracy: 0.8467
# Epoch 94/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3714 - accuracy: 0.8978
# Epoch 95/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3504 - accuracy: 0.8540
# Epoch 96/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2963 - accuracy: 0.9270
# Epoch 97/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2855 - accuracy: 0.9197
# Epoch 98/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3281 - accuracy: 0.9051
# Epoch 99/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3476 - accuracy: 0.8613
# Epoch 100/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2881 - accuracy: 0.8905
# Epoch 101/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3879 - accuracy: 0.8905
# Epoch 102/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3133 - accuracy: 0.8905
# Epoch 103/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3335 - accuracy: 0.8978
# Epoch 104/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2809 - accuracy: 0.9416
# Epoch 105/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.4027 - accuracy: 0.8540
# Epoch 106/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2367 - accuracy: 0.9197
# Epoch 107/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3594 - accuracy: 0.8759
# Epoch 108/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2527 - accuracy: 0.9343
# Epoch 109/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2071 - accuracy: 0.9124
# Epoch 110/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2546 - accuracy: 0.9416
# Epoch 111/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2884 - accuracy: 0.8978
# Epoch 112/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3167 - accuracy: 0.9124
# Epoch 113/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3510 - accuracy: 0.8832
# Epoch 114/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3541 - accuracy: 0.8613
# Epoch 115/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2342 - accuracy: 0.9124
# Epoch 116/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2488 - accuracy: 0.9051
# Epoch 117/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2386 - accuracy: 0.9343
# Epoch 118/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3238 - accuracy: 0.8905
# Epoch 119/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3282 - accuracy: 0.9124
# Epoch 120/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3451 - accuracy: 0.8905
# Epoch 121/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3182 - accuracy: 0.8686
# Epoch 122/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2824 - accuracy: 0.8978
# Epoch 123/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3058 - accuracy: 0.8832
# Epoch 124/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1942 - accuracy: 0.9343
# Epoch 125/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3091 - accuracy: 0.9197
# Epoch 126/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2600 - accuracy: 0.9270
# Epoch 127/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2398 - accuracy: 0.9124
# Epoch 128/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2308 - accuracy: 0.9343
# Epoch 129/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2822 - accuracy: 0.9197
# Epoch 130/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2112 - accuracy: 0.9343
# Epoch 131/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1826 - accuracy: 0.9197
# Epoch 132/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2029 - accuracy: 0.9197
# Epoch 133/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1753 - accuracy: 0.9416
# Epoch 134/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2366 - accuracy: 0.9124
# Epoch 135/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1980 - accuracy: 0.9343
# Epoch 136/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2260 - accuracy: 0.9270
# Epoch 137/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2167 - accuracy: 0.9124
# Epoch 138/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2667 - accuracy: 0.9197
# Epoch 139/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2467 - accuracy: 0.9343
# Epoch 140/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2666 - accuracy: 0.8978
# Epoch 141/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1765 - accuracy: 0.9416
# Epoch 142/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2783 - accuracy: 0.9124
# Epoch 143/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1623 - accuracy: 0.9343
# Epoch 144/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1396 - accuracy: 0.9635
# Epoch 145/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1971 - accuracy: 0.9416
# Epoch 146/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3449 - accuracy: 0.8759
# Epoch 147/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2893 - accuracy: 0.9051
# Epoch 148/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3085 - accuracy: 0.8832
# Epoch 149/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2148 - accuracy: 0.9270
# Epoch 150/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2266 - accuracy: 0.9197
# Epoch 151/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2347 - accuracy: 0.9124
# Epoch 152/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2501 - accuracy: 0.9270
# Epoch 153/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3117 - accuracy: 0.8832
# Epoch 154/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2468 - accuracy: 0.9197
# Epoch 155/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2154 - accuracy: 0.9270
# Epoch 156/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1411 - accuracy: 0.9489
# Epoch 157/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2222 - accuracy: 0.9416
# Epoch 158/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1749 - accuracy: 0.9416
# Epoch 159/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2872 - accuracy: 0.9124
# Epoch 160/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2691 - accuracy: 0.8905
# Epoch 161/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2781 - accuracy: 0.9051
# Epoch 162/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1946 - accuracy: 0.9343
# Epoch 163/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1226 - accuracy: 0.9781
# Epoch 164/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2367 - accuracy: 0.9343
# Epoch 165/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2563 - accuracy: 0.9197
# Epoch 166/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1974 - accuracy: 0.9197
# Epoch 167/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2244 - accuracy: 0.9343
# Epoch 168/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1395 - accuracy: 0.9562
# Epoch 169/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1782 - accuracy: 0.9416
# Epoch 170/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1937 - accuracy: 0.9343
# Epoch 171/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2833 - accuracy: 0.9051
# Epoch 172/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1966 - accuracy: 0.9489
# Epoch 173/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2091 - accuracy: 0.9197
# Epoch 174/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1948 - accuracy: 0.9489
# Epoch 175/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2282 - accuracy: 0.9197
# Epoch 176/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1990 - accuracy: 0.9270
# Epoch 177/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1201 - accuracy: 0.9708
# Epoch 178/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2673 - accuracy: 0.9197
# Epoch 179/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1814 - accuracy: 0.9343
# Epoch 180/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2716 - accuracy: 0.8978
# Epoch 181/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1974 - accuracy: 0.9343
# Epoch 182/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2846 - accuracy: 0.9197
# Epoch 183/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2028 - accuracy: 0.9489
# Epoch 184/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1317 - accuracy: 0.9708
# Epoch 185/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2401 - accuracy: 0.9416
# Epoch 186/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1704 - accuracy: 0.9343
# Epoch 187/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9781
# Epoch 188/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1478 - accuracy: 0.9562
# Epoch 189/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1750 - accuracy: 0.9489
# Epoch 190/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2601 - accuracy: 0.9124
# Epoch 191/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2233 - accuracy: 0.9343
# Epoch 192/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2059 - accuracy: 0.9343
# Epoch 193/400
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2389 - accuracy: 0.9270
# Epoch 194/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1994 - accuracy: 0.9270
# Epoch 195/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1323 - accuracy: 0.9489
# Epoch 196/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1554 - accuracy: 0.9416
# Epoch 197/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2692 - accuracy: 0.9197
# Epoch 198/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1615 - accuracy: 0.9416
# Epoch 199/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1198 - accuracy: 0.9635
# Epoch 200/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2007 - accuracy: 0.9270
# Epoch 201/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1385 - accuracy: 0.9416
# Epoch 202/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1903 - accuracy: 0.9562
# Epoch 203/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3043 - accuracy: 0.8978
# Epoch 204/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1672 - accuracy: 0.9489
# Epoch 205/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1324 - accuracy: 0.9708
# Epoch 206/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2646 - accuracy: 0.9197
# Epoch 207/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1388 - accuracy: 0.9562
# Epoch 208/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2372 - accuracy: 0.9270
# Epoch 209/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1259 - accuracy: 0.9562
# Epoch 210/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2104 - accuracy: 0.9343
# Epoch 211/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1921 - accuracy: 0.9343
# Epoch 212/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2090 - accuracy: 0.9343
# Epoch 213/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1692 - accuracy: 0.9343
# Epoch 214/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2449 - accuracy: 0.9051
# Epoch 215/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2147 - accuracy: 0.9270
# Epoch 216/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1752 - accuracy: 0.9489
# Epoch 217/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1487 - accuracy: 0.9562
# Epoch 218/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1859 - accuracy: 0.9489
# Epoch 219/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1623 - accuracy: 0.9489
# Epoch 220/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1338 - accuracy: 0.9562
# Epoch 221/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1014 - accuracy: 0.9854
# Epoch 222/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1039 - accuracy: 0.9635
# Epoch 223/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2043 - accuracy: 0.9270
# Epoch 224/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1690 - accuracy: 0.9562
# Epoch 225/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1647 - accuracy: 0.9416
# Epoch 226/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1568 - accuracy: 0.9562
# Epoch 227/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1278 - accuracy: 0.9635
# Epoch 228/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1682 - accuracy: 0.9635
# Epoch 229/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1523 - accuracy: 0.9562
# Epoch 230/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1795 - accuracy: 0.9270
# Epoch 231/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1609 - accuracy: 0.9562
# Epoch 232/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1619 - accuracy: 0.9416
# Epoch 233/400
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1172 - accuracy: 0.9562
# Epoch 234/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1530 - accuracy: 0.9489
# Epoch 235/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1324 - accuracy: 0.9416
# Epoch 236/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1046 - accuracy: 0.9635
# Epoch 237/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1233 - accuracy: 0.9562
# Epoch 238/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0698 - accuracy: 0.9927
# Epoch 239/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1338 - accuracy: 0.9635
# Epoch 240/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1054 - accuracy: 0.9562
# Epoch 241/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0981 - accuracy: 0.9781
# Epoch 242/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1274 - accuracy: 0.9562
# Epoch 243/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1819 - accuracy: 0.9562
# Epoch 244/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1117 - accuracy: 0.9708
# Epoch 245/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1500 - accuracy: 0.9489
# Epoch 246/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1053 - accuracy: 0.9635
# Epoch 247/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2484 - accuracy: 0.9270
# Epoch 248/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1152 - accuracy: 0.9489
# Epoch 249/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1664 - accuracy: 0.9416
# Epoch 250/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0875 - accuracy: 0.9562
# Epoch 251/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0810 - accuracy: 0.9854
# Epoch 252/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1978 - accuracy: 0.9343
# Epoch 253/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2203 - accuracy: 0.9343
# Epoch 254/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2087 - accuracy: 0.9197
# Epoch 255/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0898 - accuracy: 0.9781
# Epoch 256/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1025 - accuracy: 0.9708
# Epoch 257/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1345 - accuracy: 0.9416
# Epoch 258/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1455 - accuracy: 0.9416
# Epoch 259/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1575 - accuracy: 0.9416
# Epoch 260/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1774 - accuracy: 0.9562
# Epoch 261/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1200 - accuracy: 0.9708
# Epoch 262/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1614 - accuracy: 0.9489
# Epoch 263/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1485 - accuracy: 0.9489
# Epoch 264/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1203 - accuracy: 0.9635
# Epoch 265/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1370 - accuracy: 0.9416
# Epoch 266/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0670 - accuracy: 0.9927
# Epoch 267/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1410 - accuracy: 0.9562
# Epoch 268/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1616 - accuracy: 0.9343
# Epoch 269/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1838 - accuracy: 0.9343
# Epoch 270/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1728 - accuracy: 0.9562
# Epoch 271/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1226 - accuracy: 0.9781
# Epoch 272/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1528 - accuracy: 0.9489
# Epoch 273/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1284 - accuracy: 0.9562
# Epoch 274/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1203 - accuracy: 0.9635
# Epoch 275/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1567 - accuracy: 0.9635
# Epoch 276/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1112 - accuracy: 0.9708
# Epoch 277/400
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1973 - accuracy: 0.9489
# Epoch 278/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1126 - accuracy: 0.9489
# Epoch 279/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1186 - accuracy: 0.9489
# Epoch 280/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1385 - accuracy: 0.9489
# Epoch 281/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0694 - accuracy: 0.9854
# Epoch 282/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1122 - accuracy: 0.9562
# Epoch 283/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0936 - accuracy: 0.9635
# Epoch 284/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1417 - accuracy: 0.9489
# Epoch 285/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1041 - accuracy: 0.9562
# Epoch 286/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1341 - accuracy: 0.9708
# Epoch 287/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3739 - accuracy: 0.9051
# Epoch 288/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1403 - accuracy: 0.9489
# Epoch 289/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1153 - accuracy: 0.9635
# Epoch 290/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1910 - accuracy: 0.9343
# Epoch 291/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0807 - accuracy: 0.9708
# Epoch 292/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1900 - accuracy: 0.9416
# Epoch 293/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1826 - accuracy: 0.9489
# Epoch 294/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1781 - accuracy: 0.9270
# Epoch 295/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1449 - accuracy: 0.9416
# Epoch 296/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0991 - accuracy: 0.9708
# Epoch 297/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1449 - accuracy: 0.9489
# Epoch 298/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0767 - accuracy: 0.9781
# Epoch 299/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1876 - accuracy: 0.9343
# Epoch 300/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1072 - accuracy: 0.9489
# Epoch 301/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1550 - accuracy: 0.9416
# Epoch 302/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1391 - accuracy: 0.9343
# Epoch 303/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0695 - accuracy: 0.9854
# Epoch 304/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1431 - accuracy: 0.9489
# Epoch 305/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1807 - accuracy: 0.9489
# Epoch 306/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1111 - accuracy: 0.9489
# Epoch 307/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2088 - accuracy: 0.9197
# Epoch 308/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1843 - accuracy: 0.9416
# Epoch 309/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1092 - accuracy: 0.9708
# Epoch 310/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0951 - accuracy: 0.9635
# Epoch 311/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1336 - accuracy: 0.9635
# Epoch 312/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1193 - accuracy: 0.9562
# Epoch 313/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1854 - accuracy: 0.9562
# Epoch 314/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1058 - accuracy: 0.9708
# Epoch 315/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1828 - accuracy: 0.9051
# Epoch 316/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1131 - accuracy: 0.9489
# Epoch 317/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1698 - accuracy: 0.9562
# Epoch 318/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1275 - accuracy: 0.9562
# Epoch 319/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1371 - accuracy: 0.9489
# Epoch 320/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1078 - accuracy: 0.9562
# Epoch 321/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1271 - accuracy: 0.9635
# Epoch 322/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1472 - accuracy: 0.9562
# Epoch 323/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1257 - accuracy: 0.9562
# Epoch 324/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2019 - accuracy: 0.9197
# Epoch 325/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1656 - accuracy: 0.9270
# Epoch 326/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1676 - accuracy: 0.9270
# Epoch 327/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9708
# Epoch 328/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1410 - accuracy: 0.9270
# Epoch 329/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1529 - accuracy: 0.9562
# Epoch 330/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0825 - accuracy: 0.9781
# Epoch 331/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1382 - accuracy: 0.9562
# Epoch 332/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0826 - accuracy: 0.9854
# Epoch 333/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1619 - accuracy: 0.9562
# Epoch 334/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1546 - accuracy: 0.9562
# Epoch 335/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1399 - accuracy: 0.9562
# Epoch 336/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1273 - accuracy: 0.9635
# Epoch 337/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1485 - accuracy: 0.9270
# Epoch 338/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1426 - accuracy: 0.9562
# Epoch 339/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1762 - accuracy: 0.9416
# Epoch 340/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0617 - accuracy: 0.9781
# Epoch 341/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1635 - accuracy: 0.9197
# Epoch 342/400
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0789 - accuracy: 0.9854
# Epoch 343/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0915 - accuracy: 0.9781
# Epoch 344/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1944 - accuracy: 0.9343
# Epoch 345/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2039 - accuracy: 0.9197
# Epoch 346/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1401 - accuracy: 0.9635
# Epoch 347/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1304 - accuracy: 0.9416
# Epoch 348/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1118 - accuracy: 0.9635
# Epoch 349/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0598 - accuracy: 0.9708
# Epoch 350/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1053 - accuracy: 0.9489
# Epoch 351/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1156 - accuracy: 0.9635
# Epoch 352/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1816 - accuracy: 0.9343
# Epoch 353/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0976 - accuracy: 0.9562
# Epoch 354/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0556 - accuracy: 0.9781
# Epoch 355/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0493 - accuracy: 0.9927
# Epoch 356/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1023 - accuracy: 0.9562
# Epoch 357/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1292 - accuracy: 0.9562
# Epoch 358/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2113 - accuracy: 0.9270
# Epoch 359/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1686 - accuracy: 0.9562
# Epoch 360/400
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1526 - accuracy: 0.9343
# Epoch 361/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1573 - accuracy: 0.9416
# Epoch 362/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2100 - accuracy: 0.9562
# Epoch 363/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1354 - accuracy: 0.9708
# Epoch 364/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0812 - accuracy: 0.9854
# Epoch 365/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0977 - accuracy: 0.9635
# Epoch 366/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1131 - accuracy: 0.9562
# Epoch 367/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0822 - accuracy: 0.9635
# Epoch 368/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1905 - accuracy: 0.9343
# Epoch 369/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1101 - accuracy: 0.9562
# Epoch 370/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1415 - accuracy: 0.9489
# Epoch 371/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0986 - accuracy: 0.9635
# Epoch 372/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1084 - accuracy: 0.9635
# Epoch 373/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1406 - accuracy: 0.9562
# Epoch 374/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1501 - accuracy: 0.9416
# Epoch 375/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0745 - accuracy: 0.9781
# Epoch 376/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1598 - accuracy: 0.9343
# Epoch 377/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9489
# Epoch 378/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0790 - accuracy: 0.9781
# Epoch 379/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1236 - accuracy: 0.9562
# Epoch 380/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0920 - accuracy: 0.9708
# Epoch 381/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1479 - accuracy: 0.9489
# Epoch 382/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1602 - accuracy: 0.9489
# Epoch 383/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1345 - accuracy: 0.9489
# Epoch 384/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1266 - accuracy: 0.9489
# Epoch 385/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0891 - accuracy: 0.9708
# Epoch 386/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0755 - accuracy: 0.9781
# Epoch 387/400
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0887 - accuracy: 0.9635
# Epoch 388/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0972 - accuracy: 0.9781
# Epoch 389/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1200 - accuracy: 0.9489
# Epoch 390/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1065 - accuracy: 0.9635
# Epoch 391/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1323 - accuracy: 0.9489
# Epoch 392/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0818 - accuracy: 0.9781
# Epoch 393/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0560 - accuracy: 0.9781
# Epoch 394/400
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1541 - accuracy: 0.9635
# Epoch 395/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0763 - accuracy: 0.9635
# Epoch 396/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0937 - accuracy: 0.9562
# Epoch 397/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1542 - accuracy: 0.9489
# Epoch 398/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0801 - accuracy: 0.9708
# Epoch 399/400
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2411 - accuracy: 0.9270
# Epoch 400/400
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1628 - accuracy: 0.9562
# model_emb created

# %% [markdown]
# ### Testing NN

# %%
# trial
testing_test = "what is word embeddings"
# testing the tfidf approach
np.argmax(model_tfidf.predict((tf_neural.transform([testing_test])).todense()))
# testing the embedding approach
index = np.argmax(model_emb.predict(embedder.encode(testing_test).reshape(1,-1)))

# %%
# getting the label
for key, value in label_decoder.items():
  if np.argmax(value) == index:
    print(key)
# Out:
# Natural Language Processing

# %% [markdown]
# # **Information Retrieval (IR)**

# %% [markdown]
# ## Data Preparation

# %%
# Reading the NLP corpus
corpus = open('/content/drive/MyDrive/NLP Project Corpus.txt','r')
corpus = corpus.read()

# %%
# Sentence segmentation
doc = nlp(corpus)
sentences = [sent.text for sent in doc.sents]

# %%
# Saving sentences in a dataframe
df = pd.DataFrame()
df["sentences"] = sentences

# %% [markdown]
# ## NLP Corpus Preprocessing (Indexing)

# %%
def normalize_nlp_document(text, normMethod):
    # lower case and remove special characters\whitespaces
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text, re.I|re.A)
    text = text.lower()
    # removing wikipedia references (many texts are from wiki)
    text = re.sub(r'\[\d\]', '',text)
    # tokenize document
    tokens = nltk.word_tokenize(text)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in STOP_WORDS]
    # Stemming 
    if normMethod == "stemming":
      porter = PorterStemmer()
      stems = [porter.stem(token) for token in filtered_tokens]
      # re-create document from filtered tokens
      text = ' '.join(stems)
      return text
    # Lemmatization
    elif normMethod == "lemmatization":
       text = ' '.join(filtered_tokens)
       doc = nlp(text)
       lemmas = [token.lemma_ for token in doc]
       # re-create document from lemmas
       text = ' '.join(lemmas)
       return text

# %%
# Adding normalized sentence columns
df['stemming normalized sentences'] = df['sentences'].apply(normalize_nlp_document, normMethod='stemming')
df['lemmatization normalized sentences'] = df['sentences'].apply(normalize_nlp_document, normMethod='lemmatization')

# %% [markdown]
# ## IR with Stemming

# %%
def retrieve_using_stemming(query):
  # Weighting using tfidf
  tf = TfidfVectorizer()
  tf_matrix = tf.fit_transform(df['stemming normalized sentences'])

  # Query preprocessing
  query = normalize_nlp_document(query,'stemming')
  mat = tf.transform([query])

  # Comparison
  query_doc_sim = cosine_similarity(mat,tf_matrix)[0]
  top_rel =  (-query_doc_sim).argsort()[0:3]
  docs = df.iloc[top_rel]
  return docs['sentences'].iloc[0]

# %% [markdown]
# ## IR with Lemmatization

# %%
def retrieve_using_lemmatization(query):
  # Weighting using tfidf
  tf = TfidfVectorizer()
  tf_matrix = tf.fit_transform(df['lemmatization normalized sentences'])

  # Query preprocessing
  query = normalize_nlp_document(query,'lemmatization')
  mat = tf.transform([query])

  # Comparison
  query_doc_sim = cosine_similarity(mat,tf_matrix)[0]
  top_rel =  (-query_doc_sim).argsort()[0:3]
  docs = df.iloc[top_rel]
  return docs['sentences'].iloc[0]

# %% [markdown]
# # **Response Generation**

# %%
intent_responses_dic = {}
for intent in intents_patterns['intents']:
  intent_responses_dic[intent['tag']] = intent['responses']

# %%
message = input("Message: ")
norm_message = normalize_doc(message)
index = np.argmax(model_emb.predict(embedder.encode(norm_message).reshape(1,-1)))
# getting the label
for key, value in label_decoder.items():
  if np.argmax(value) == index:
    if key != "Natural Language Processing":
      response = random.choice(intent_responses_dic[key])
      print(response)
    elif key == "Natural Language Processing":
      print(retrieve_using_stemming(message))
# Out:
# Message: What is your name?
# I am Dr. Mireille's assistant bot
